# %% [markdown]
# # Conocenos

# %% [markdown]
# <div style="display: flex; align-items: flex-start; gap: 20px;">
# <img src="https://www.hackods.unam.mx/assets/logos/hackods_unam_logo.png" alt="Logo HackODS" style="width: 400px;">
# <div>
#
# **Código Guinda**
#
# Integrantes: Elias Montejo Hernández, Jaretzy Pérez Ramón & José Francisco Pérez Ramón
#
# <div style="display: flex; align-items: center; gap: 10px;">
#   <img src="https://upload.wikimedia.org/wikipedia/commons/7/74/Sustainable_Development_Goal-es-14.jpg" style="width: 100px;">
#   <p>OSD: 04 - Educación de calidad</p>
# </div>
# </div>
#
# </div>
#
# Este proyecto analiza la educación en comunidades indígenas de Chiapas, resaltando los factores que limitan el acceso equitativo al aprendizaje. A través de un enfoque reflexivo, se examina cómo el lugar de origen, la pobreza y las barreras lingüísticas influyen en las oportunidades educativas de los estudiantes.
#
# This work is licensed under <a href="https://creativecommons.org/licenses/by-sa/4.0/">CC BY-SA 4.0</a><img src="https://mirrors.creativecommons.org/presskit/icons/cc.svg" alt="" style="max-width: 1em;max-height:1em;margin-left: .2em;"><img src="https://mirrors.creativecommons.org/presskit/icons/by.svg" alt="" style="max-width: 1em;max-height:1em;margin-left: .2em;"><img src="https://mirrors.creativecommons.org/presskit/icons/sa.svg" alt="" style="max-width: 1em;max-height:1em;margin-left: .2em;">

# %% [markdown]
# ## 0. Activar librerías

# %%
import plotly.graph_objects as go
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Rezago educativo

# %% [markdown]
# ## **Porcentaje de rezago educativo por entidad en 2024**

# %% [markdown]
# En una comunidad indígena de Chiapas, una niña camina todos los días para llegar a la escuela. Aunque siempre va con el ánimo de aprender, muchas veces no comprende completamente las clases, ya que se imparten en español y su lengua materna es otra. Además, al llegar a casa, tiene que hacer rápidamente su tarea porque después debe salir a trabajar con su mamá, debido a que su familia cuenta con escasos recursos.
# Esta hecho evidencia que el acceso a la educación no es igual para todos y depende de diversos factores sociales y económicos. Ante ello, surge una pregunta fundamental: ¿hasta qué punto el lugar donde nace una persona determina sus oportunidades educativas?
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/c/cd/Escuela_ind%C3%ADgena_en_el_Municipio_de_San_Jos%C3%A9_del_Rinc%C3%B3n.jpg" style="width: 500px;">
# <a href="https://commons.wikimedia.org/wiki/File:Escuela_ind%C3%ADgena_en_el_Municipio_de_San_Jos%C3%A9_del_Rinc%C3%B3n.jpg">Government of Mexico</a>, Public domain, via Wikimedia Commons

# %%
ruta= "C:/Users/jaryp/Desktop/Codigo_G/datos/Rezago_educativo_entid.csv"
df = pd.read_csv(ruta, encoding="latin1", index_col=0, skiprows=0)
df
# Out:
#                                  Porcentaje
# Estados
# Chiapas                                34.0
# Oaxaca                                 30.5
# Guerrero                               28.3
# Veracruz de Ignacio de la Llave        26.3
# Michoacán de Ocampo                    25.7
# Puebla                                 22.7
# Guanajuato                             21.1
# Campeche                               20.5
# Yucatán                                19.7
# Jalisco                                19.1
# San Luis Potosí                        18.8
# Zacatecas                              18.8
# Nayarit                                18.4
# Hidalgo                                18.0
# Tabasco                                17.9
# Durango                                17.7
# Morelos                                17.4
# Chihuahua                              16.6
# Quintana Roo                           16.0
# Sinaloa                                15.5
# ...

# %%
fig = px.bar(df, x="Porcentaje", y= df.index, title="Rezago educativo por entidad 2024", color_discrete_sequence=['red'] ,height=1000)
fig.update_xaxes(range=[5, 35], ticks="outside")
fig.show()

# %% [markdown]
# En el caso de las comunidades de Chiapas, el lugar de origen inlfuye en las oportunidades educativas. De acuerdo con datos del INEGI, el estado presenta uno de los niveles más altos de rezago educativo en el país. Las carencias sociales y su vulnerabilidad provoca que muchos estudiantes no puedan continuar con sus estudios.

# %% [markdown]
# **Grado promedio de escolaridad por entidad en 2020**

# %% [markdown]
# Se observa que entidades como Chiapas, Oaxaca y Guerrero presentan los niveles más altos de rezago educativo y el grado promedio de escolaridad son los más bajos en el país. Esto indica que el rezago educativo afecta principalmente a las regiones con mayores condiciones de vulnerabilidad y está fuertemente relacionado con factores como el desarrollo económico, el acceso a servicios educativos y las condiciones sociales.

# %%
ruta= "C:/Users/jaryp/Desktop/Codigo_G/datos/Grad_prom_escol_entid.csv"
df = pd.read_csv(ruta, encoding="latin1", index_col=0, skiprows=0)
df
# Out:
#                                  Grado promedio
# Área geográfica
# Chiapas                                     7.8
# Oaxaca                                      8.1
# Guerrero                                    8.4
# Michoacán de Ocampo                         8.6
# Veracruz de Ignacio de la Llave             8.7
# Guanajuato                                  9.0
# Puebla                                      9.2
# Zacatecas                                   9.2
# Hidalgo                                     9.4
# Campeche                                    9.6
# San Luis Potosí                             9.6
# Yucatán                                     9.6
# Durango                                     9.7
# Nayarit                                     9.7
# Tabasco                                     9.7
# Morelos                                     9.8
# Tlaxcala                                    9.8
# Jalisco                                     9.9
# ...

# %% [markdown]
# El promedio de escolaridad en Chiapas es de apenas 8 años, lo que significa que muchas niñas y niños dejan de estudiar empezando la primaria. Esta situación refleja las dificultades que enfrentan miles de niñas, niños y jóvenes para permanecer en el sistema educativo, evidenciando una problemática que limita su desarrollo personal y sus oportunidades a futuro.

# %% [markdown]
# # Lengua indígena

# %% [markdown]
# ## **Estados con mayor población que habla lengua indígena**

# %% [markdown]
# El entorno en las aulas continúan con una barrera lingüística, cunado las niñas y niños llegan la etapa de la educación básica y en los centros educativos se encuentran con profesores que no hablan su lengua originaria. Esa diferencia no es menor, implica aprender en una lengua que no dominan completamente, lo que dificulta la comprensión y desempeño académico. Por lo tanto, la educación bilingüe es fundamental para mejorar el aprendizaje de niñas y niños indígenas.

# %%
ruta = "C:/Users/jaryp/Desktop/Codigo_G/datos/Pob_Lengua_indigena.xlsx"
df = pd.read_excel(ruta, index_col=0, skiprows=6)
df
# Out:
#                                     2010     2020
# Entidad federativa
# Chiapas                          1209057  1459648
# Oaxaca                           1203150  1221555
# Veracruz de Ignacio de la Llave   662760   663503
# Puebla                            617504   615622
# Yucatán                           544927   525092
# Guerrero                          481098   515487
# México                            379075   417603
# Hidalgo                           369549   362629
# San Luis Potosí                   256468   231213
# Quintana Roo                      198587   204949
# Michoacán de Ocampo               140820   154943
# Ciudad de México                  123224   125153
# Chihuahua                         109378   110498
# Campeche                           92128    91801
# Tabasco                            61256    91025
# Nuevo León                         40528    77945
# Nayarit                            52833    69069
# ...

# %%
df_filtrado= df.loc[["Chiapas", "Oaxaca", "Veracruz de Ignacio de la Llave"]]
df_filtrado
# Out:
#                                     2010     2020
# Entidad federativa
# Chiapas                          1209057  1459648
# Oaxaca                           1203150  1221555
# Veracruz de Ignacio de la Llave   662760   663503

# %%
fig = px.bar(df_filtrado, x="2020", y= df_filtrado.index, color_discrete_sequence=['yellow'],height=200)
fig.update_xaxes(range=[500000, 1500000], ticks="outside")
fig.show()

# %% [markdown]
# Chiapas, Oaxaca y Veracruz son los estados con mayor número de hablantes de lengua indígena en el país. En el caso de Chiapas, existen municipios con una alta concentración de población hablante de lenguas indígenas.

# %% [markdown]
# **Población hablante de lengua indígena en municipios de Chiapas**

# %%
ruta= "C:/Users/jaryp/Desktop/Codigo_G/datos/Pob_indigena_minicipio.csv"
df = pd.read_csv(ruta, encoding="latin1", index_col=4, skiprows=0)
df
# Out:
#                             _id  clave_entidad entidad_federativa  \
# Municipio
# Ocosingo                    131              7            Chiapas
# Chilón                      103              7            Chiapas
# San Cristóbal de las Casas  150              7            Chiapas
# Chamula                      95              7            Chiapas
# Las Margaritas              124              7            Chiapas
# ...                         ...            ...                ...
# Metapa                      127              7            Chiapas
# Nicolás Ruí­z               130              7            Chiapas
# Bejucal de Ocampo            82              7            Chiapas
# Sunuapa                     160              7            Chiapas
# Capitán Luis Ángel Vidal    191              7            Chiapas
#
#                             clave_municipio               grupo  Poblacion
# Municipio
# Ocosingo                               7059  Población indígena     210294
# ...

# %%
df_filtrado = df.loc[["Ocosingo", "Chilón", "San Cristóbal de las Casas","Chamula"]]
df_filtrado
# Out:
#                             _id  clave_entidad entidad_federativa  \
# Municipio
# Ocosingo                    131              7            Chiapas
# Chilón                      103              7            Chiapas
# San Cristóbal de las Casas  150              7            Chiapas
# Chamula                      95              7            Chiapas
#
#                             clave_municipio               grupo  Poblacion
# Municipio
# Ocosingo                               7059  Población indígena     210294
# Chilón                                 7031  Población indígena     134720
# San Cristóbal de las Casas             7078  Población indígena     103810
# Chamula                                7023  Población indígena     102760

# %%
fig = px.bar(df_filtrado, x="Poblacion", y= df_filtrado.index, color_discrete_sequence=['blue'],height=200)
fig.update_xaxes(range=[100000, 220000], ticks="outside")
fig.show()

# %% [markdown]
# **Municipios con mayor número de hablantes de lengua indígena en Chiapas**

# %%
ruta= "C:/Users/jaryp/Desktop/Codigo_G/datos/Pob_lengua_munic_Chiapas.csv"
df = pd.read_csv(ruta, encoding="latin1", index_col=1, skiprows=3)
df.head(10)
# Out:
#                              clave  Población
# Área geográfica
# Ocosingo                    7059.0     151046
# Chilón                      7031.0     112229
# Chamula                     7023.0      86628
# San Cristóbal de las Casas  7078.0      64906
# Tila                        7096.0      60552
# Las Margaritas              7052.0      58692
# Palenque                    7065.0      49130
# Salto de Agua               7077.0      47332
# Oxchuc                      7064.0      44968
# Tenejapa                    7093.0      40630

# %%
df = df.drop(["clave"],axis=1)
df
# Out:
#                             Población
# Área geográfica
# Ocosingo                       151046
# Chilón                         112229
# Chamula                         86628
# San Cristóbal de las Casas      64906
# Tila                            60552
# ...                               ...
# Bejucal de Ocampo                  18
# Capitán Luis Ángel Vidal           12
# Sunuapa                            12
# Honduras de la Sierra               7
# NaN                           1387295
#
# [125 rows x 1 columns]

# %%
df_filtrado = df.loc[["Ocosingo", "Chilón", "Chamula"]]
df_filtrado
# Out:
#                  Población
# Área geográfica
# Ocosingo            151046
# Chilón              112229
# Chamula              86628

# %%
fig = px.bar(df_filtrado, x="Población", y= df_filtrado.index, color_discrete_sequence=['purple'],height=200)

fig.show()

# %% [markdown]
# Los municipios con mayor población de hablantes de lengua indígena son Ocosingo, Chilón y Chamula, donde predominan lenguas como el tzeltal, el tzotzil y el ch´ol. Esta diversidad lingüística refleja una riqueza cultural importante, pero también evidencia desafíos en el acceso a una educación inclusiva.

# %% [markdown]
# **Municipios con mayor porcentanje de pobreza de la población indígena de Chiapas**

# %% [markdown]
# En Chiapas, 8 de cada 10 personas indígenas viven en condiciones de pobreza, lo que limita las oportunidades educativas.

# %%
ruta= "C:/Users/jaryp/Desktop/Codigo_G/datos/Pob_Indgna_municipio_pobreza.csv"
df = pd.read_csv(ruta, encoding="latin1", index_col=4, skiprows=0)
df
# Out:
#                            id  clave_entidad Entidad_federativa  \
# Municipio
# San Juan Cancuc           183              7            Chiapas
# Chanal                     96              7            Chiapas
# Aldama                    184              7            Chiapas
# Chalchihuitán              94              7            Chiapas
# Chenalhó                   98              7            Chiapas
# San Andrés Duraznal       189              7            Chiapas
# Mitontic                  128              7            Chiapas
# Oxchuc                    136              7            Chiapas
# Tila                      167              7            Chiapas
# Pantelhó                  138              7            Chiapas
# Rincón Chamula San Pedro  192              7            Chiapas
# Sitalá                    154              7            Chiapas
# Totolapa                  169              7            Chiapas
# ...

# %%
df1 = df.drop(['id','clave_entidad','Entidad_federativa','Clave_municipio','Grupo','poblacion'], axis =1 )
df1
# Out:
#                           Pobreza
# Municipio
# San Juan Cancuc             99.27
# Chanal                      99.12
# Aldama                      98.95
# Chalchihuitán               98.88
# Chenalhó                    98.69
# San Andrés Duraznal         98.52
# Mitontic                    98.40
# Oxchuc                      98.13
# Tila                        98.10
# Pantelhó                    98.02
# Rincón Chamula San Pedro    97.90
# Sitalá                      97.71
# Totolapa                    97.70
# Maravilla Tenejapa          97.46
# Simojovel                   97.46
# Santiago el Pinar           97.29
# Las Margaritas              97.21
# Jitotol                     97.20
# Huixtán                     97.13
# Tenejapa                    97.11

# %%
df_filtrado=  df1.loc[["San Juan Cancuc", "Chanal", "Aldama","Chalchihuitán","Chenalhó","San Andrés Duraznal","Mitontic","Oxchuc","Tila","Pantelhó"]]
df_filtrado
# Out:
#                      Pobreza
# Municipio
# San Juan Cancuc        99.27
# Chanal                 99.12
# Aldama                 98.95
# Chalchihuitán          98.88
# Chenalhó               98.69
# San Andrés Duraznal    98.52
# Mitontic               98.40
# Oxchuc                 98.13
# Tila                   98.10
# Pantelhó               98.02

# %%
fig = px.bar(df_filtrado, x='Pobreza',y= df_filtrado.index, color_discrete_sequence=['orange'])
fig.update_xaxes(range=[97, 100])
fig.show()

# %% [markdown]
# Resulta preocupante observar que el porcentaje de pobreza de la población indígena en estos municipios es demasiado alto. Esta situación implica múltiples carencias que afectan directamente la posibilidad de acceder a una educación de calidad.Por un lado, la falta de recursos económicos limita el acceso a materiales escolares, transporte y alimentación adecuada, elementos básicos para el aprendizaje. Por otro, las condiciones de vida obligan a muchos niños y jóvenes a incorporarse al trabajo desde edades tempranas, reduciendo el tiempo y la energía que pueden dedicar a sus estudios.
#
#  <img src="https://upload.wikimedia.org/wikipedia/commons/8/85/Mujeres_Ind%C3%ADgenas_en_San_Juan_Chamula.jpg" style="width: 400px ;">
# <a href="https://commons.wikimedia.org/wiki/File:Mujeres_Ind%C3%ADgenas_en_San_Juan_Chamula.jpg">WendyAvilesR</a>, <a href="https://creativecommons.org/licenses/by-sa/4.0">CC BY-SA 4.0</a>, via Wikimedia Commons

# %% [markdown]
# Esta realidad evidencia una profunda desigualdad, mientras algunos estudiantes cuentan con recursos y apoyos, otros enfrentan múltiples barreras desde el inicio, lo que convierte la educación en un privilegio más que un derecho garantizado.

# %% [markdown]
# # Servicios educativos

# %% [markdown]
# ## **Servicios educativos que presta educación indígena en diversos municipios del estado de Chiapas**

# %%
ruta = "C:/Users/jaryp/Desktop/Codigo_G/datos/Serv_educa_presta_edu_indgna.xlsx"
df = pd.read_excel(ruta, index_col=0, skiprows=0)
df
# Out:
#                             Primaria  Preescolar  Inicial  Albergues
# Nombre de municipio
# Chilon                           265         150       33         11
# Ocosingo                         223         140       27         14
# Las margaritas                   118          86        4         12
# Chamula                          104          78        0          3
# Palenque                          97          65        2          5
# Tila                              89          69        7          7
# Salto de agua                     87          59        7          5
# Oxchuc                            78          49        6          3
# Motozintla                        66          28        2          4
# Chanalho                          62          54        1          5
# Tenejapa                          50          44        2          2
# Simojovel                         49          36       11          1
# ...

# %%
df.plot.bar(stacked=True, figsize=(12,6));

# %% [markdown]
# A pesar de este panorama, existen esfuerzos orientados a mejorar la situación educativa en las comunidades indígenas, como los programas de educación bilingüe. Estos avances resultan aún limitados frente a la magnitud del problema. Esta realidad invita a reflexionar sobre la necesidad de fortalecer políticas educativas verdaderamente incluyentes, que reconozcan y atiendan las condiciones sociales, culturales y lingüísticas de estas comunidades. Solo así será posible avanzar hacia una educación que no sea un privilegio de unos cuantos, sino un derecho efectivo y garantizado para todos.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/1/1f/Misi%C3%B3n_OMS_Chimix_Chiapas_M%C3%A9xico.jpg" style="width: 500px;">
# <a href="https://commons.wikimedia.org/wiki/File:Misi%C3%B3n_OMS_Chimix_Chiapas_M%C3%A9xico.jpg">Lyarzabal</a>, <a href="https://creativecommons.org/licenses/by-sa/4.0">CC BY-SA 4.0</a>, via Wikimedia Commons

# %% [markdown]
# Es momento de dejar de observar la crisis educativa en Chiapas como un fenómeno distante. Frente a esta realidad, la educación en comunidades indígenas de Chiapas deja de ser solo un problema social y se convierte en una responsabilidad compartida. El rezago educativo es consecuencias de las condiciones sociales y económicas en las que viven muchas personas. Como sociedad tenemos que exigir mejores políticas educativas para contribuir a reducir estas brechas.
# La educación de calidad no debería depender del lugar donde nace, sino ser un derecho garantizado para todos.

# %% [markdown]
# **¿Qué futuro estamos construyendo si no todos tienen las mismas oportunidades de aprender?**

# %% [markdown]
# # Metadatos

# %% [markdown]
# Fuente: Instituto Nacional de Estadística y Geografía 2024 (https://www.inegi.org.mx/app/tabulados/pxwebclient/default.html?pxq=BISE_BISE_0AojJWW6_260410180243_857b58e4-4535-4ae2-8b62-063f558de743)
# + Fecha de descarga: 09-marzo-2026
# + Licencia: Uso libre
# + Descripción de variables por dataset: Área geográfica, porcentaje de población en rezago educativo
#
# Fuente: Instituto Nacional de Estadística y Geografía 2020 (https://www.inegi.org.mx/app/tabulados/pxwebclient/default.html?pxq=BISE_BISE_0AojJWW6_260410180243_089119d7-2fac-41e4-a066-de287e4eb691)
# + Fecha de descarga: 09-marzo-2026
# + Licencia: Uso libre
# + Descripción de variables por dataset: Área geográfica, grado promedio de escolaridad
#
# Fuente: Instituto Nacional de Estadística y Geografía 2020 (https://www.inegi.org.mx/app/tabulados/pxwebclient/default.html?pxq=BISE_BISE_0AojJWW6_260410180243_255e89bc-7fbc-438f-a069-b5583dde7b01)
# + Fecha de descarga: 08-marzo-2026
# + Licencia: Uso libre
# + Descripción de variables por dataset: Área geográfica, población que habla lengua indigena nivel estatal
#
# Fuente: Instituto Nacional de Estadística y Geografía (https://www.inegi.org.mx/app/tabulados/pxwebclient/default.html?pxq=BISE_BISE_ObiNLWW6_260409145452_f71468ef-7dce-44a6-9c4a-2e440f6eb7de)
# + Fecha de descarga: 09-marzo-2026
# + Licencia: Uso libre
# + Descripción de variables por dataset: Área geográfica, población que habla lengua indigena nivel municipal en Chiapas
#
# Fuente: Datos Abiertos de México (https://www.datos.gob.mx/dataset/pobreza_mexico/resource/1e5a4536-b6dd-4dde-900a-7198797d9843)
# + Fecha de descarga: 08-marzo-2026
# + Licencia: Creative Commons Attribution 4.0
# + Descripción de variables por dataset: Población indígena, en pobreza y que habla lengua indígena a nivel municipal en Chiapas
#
# Fuente:  Dirección de Educación Indígena (https://www.educacionchiapas.gob.mx/docentes-y-administrativos/subsecretaria-de-educacion-federalizada/educacion-indigena/)
# + Fecha de descarga: 09-marzo-2026
# + Licencia: Uso público gubernamental
# + Descripción de variables por dataset: Servicios educativos que presta educación indígena en diversos municipios del estado de Chiapas
